# %% [markdown]
# <a href="https://colab.research.google.com/github/Markl900/my-notebooks/blob/main/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/dsollberger/quartoblog/master/posts/office_sentiment/office_sentiment.csv"

office_df = pd.read_csv(url)
office_df.head()
# Out:
#    index  season  episode episode_name    director  \
# 0      1       1        1        Pilot  Ken Kwapis
# 1      2       1        1        Pilot  Ken Kwapis
# 2      3       1        1        Pilot  Ken Kwapis
# 3      4       1        1        Pilot  Ken Kwapis
# 4      5       1        1        Pilot  Ken Kwapis
#
#                                         writer character  \
# 0  Ricky Gervais;Stephen Merchant;Greg Daniels   Michael
# 1  Ricky Gervais;Stephen Merchant;Greg Daniels       Jim
# 2  Ricky Gervais;Stephen Merchant;Greg Daniels   Michael
# 3  Ricky Gervais;Stephen Merchant;Greg Daniels       Jim
# 4  Ricky Gervais;Stephen Merchant;Greg Daniels   Michael
#
#                                                 text  \
# 0  All right Jim. Your quarterlies look very good...
# 1         Oh, I told you. I couldn't close it. So...
# 2  So you've come to the master for guidance? Is ...
# 3         Actually, you called me in here, but yeah.
# ...

# %%
import matplotlib.pyplot as plt

# %%
office_df.isnull().sum()
# Out:
# index                         0
# season                        0
# episode                       0
# episode_name                  0
# director                      0
# writer                        0
# character                     0
# text                        377
# text_w_direction              5
# imdb_rating                   0
# total_votes                   0
# air_date                      0
# sentimentAnalysis_score    3412
# sentimentr_score              0
# syuzhet_score                 0
# dtype: int64

# %%
office_df.head()
office_df = office_df.dropna(subset=['text'])
office_df = office_df.dropna(subset=['sentimentAnalysis_score'])
office_df.isnull().sum()

office_df.isnull().sum()
# Out:
# index                      0
# season                     0
# episode                    0
# episode_name               0
# director                   0
# writer                     0
# character                  0
# text                       0
# text_w_direction           0
# imdb_rating                0
# total_votes                0
# air_date                   0
# sentimentAnalysis_score    0
# sentimentr_score           0
# syuzhet_score              0
# dtype: int64

# %%
office_df.isnull().sum().sum()
# Out:
# np.int64(0)
